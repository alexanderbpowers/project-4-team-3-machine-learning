# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
from splinter import Browser
import requests
from webdriver_manager.chrome import ChromeDriverManager

# %%
# from selenium import webdriver

# executable_path = {'executable_path': ChromeDriverManager().install()}
# browser = Browser('chrome', **executable_path, headless=False)
# url = "https://www.news.com.au//"
# driver = webdriver.Chrome("/Users/alexanderpowers/Downloads/chromedriver")
# driver.get(url)
# html = driver.page_source
# soup = bs(html, 'html.parser')

url = 'https://www.news.com.au/'
response = requests.get(url)
soup = bs(response.text, 'html.parser')

# %%
titles = soup.find_all('h4', class_="storyblock_title")

title_li = []

for title in titles:
    title_li.append(title.text)

title_li
# Out:
# ['PRE-SCHOOL MASSACRE: At least 31 dead in horrific mass shooting',
#  'Explosive CCTV after homophobic barista rant',
#  'Robert Irwin makes major announcement',
#  'Lisa ‘angry’ when Higgins interview aired',
#  'Teen charged after Optus hack scam',
#  'Musk mercilessly roasted over Ukraine map',
#  'Star heartbroken by body shame storm',
#  'Ex-Big Bash star in custody on rape charges',
#  'Urgent tornado warning for NSW and Vic',
#  'NRL superstar’s bombshell $4m decision',
#  '‘Obsessed’: Woman’s housemate horror',
#  'Bestselling Birkenstocks on sale from $79',
#  'North Korea fires two ballistic missiles, blames US for ‘escalation’',
#  'Iranian Kurd exiles in Iraq under fire as protests rage',
#  '‘Major’ delays as tracks flooded',
#  'Mega ASICS Gel-Kayano 29 sale',
#  'Britney’s raunchiest nude photo shoot yet',
#  'World’s oldest supermodel’s nude shoot',
#  'Amanda Keller drops big news live on air',
#  'Massive news for MasterChef fans',
#  'Star speaks out about ‘abusive’ film set',
#  'Disturbing find on Sydney beach',
#  'NRL superstar’s bombshell $4m decision',
#  'Photo that shows Australia has lost its way',
#  '‘Major’ delays as tracks flooded',
#  'AFLW star refuses to wear rainbow jersey',
#  '‘OMG’: Chess fans lose it over awkward photo',
#  'Cancelled trip creates $52K nightmare',
#  'Musk’s cheeky request on Twitter deal',
#  '‘I’m not talking to you’: Saudi prince erupts',
#  'Boxing champ’s stunning body transformation',
#  '‘Free’ Teslas to come with new Sydney homes',
#  '41-room mansion has its own zoo, lake',
#  'Expert’s warning when interest rates could peak',
#  'Horror find when doctor opened body bag',
#  'Neighbour’s chilling letter for cat owner',
#  '‘Detox’: Easy trick to a better sex life',
#  'Deadly reason for spots on 3yo’s tongue',
#  '‘Love it!’: Woman’s Kmart creation stuns',
#  '’Polite’ email habit annoying your colleagues',
#  'Mum hacks famous ‘Bluey’ duck cake for $4.80',
#  'Jules sparks frenzy over Cotton On dress',
#  'Aussies set to lose ‘millions’ this weekend',
#  '111yo mystery ship found off coast of WA',
#  'Horrendous pain from suicide bombing',
#  'Hotel guest busts staffer in ‘alarming’ act',
#  'Leaked email exposes Qantas nightmare',
#  'Lawyer calls out cops over festival tactic',
#  'Fans back Block stars over ‘racist’ edit',
#  'Jilted MAFS groom’s bold new move',
#  'Mansion where Depp severed finger sold',
#  '‘Your family are liars’: Kanye erupts',
#  'Google reveals Australia’s top searches',
#  'North Korea ignores global fury, fires missile',
#  'Wild change to legendary muscle car',
#  '‘Lucky to be alive’: Cops survive horror crash',
#  '‘Enormous’ rain event worrying forecasters',
#  '‘Out of control’: Bold move to fix rent hike',
#  'Family’s ‘nightmare’ over ‘castle’ next door',
#  'Huge rise in Australia’s most in-demand jobs',
#  'Cash boost for one group starts today',
#  '‘Tough’: Aussies missing out on $283k',
#  'Big call on Wayne Carey white powder saga',
#  '‘Staggered’: AFL club ‘irate’ as deal implodes',
#  '‘I’m good’: Freakish Kyrgios surprises himself',
#  '‘How can you say that?’: AFL drama explodes',
#  'Eels star ‘one of the tightest you’ll meet’',
#  'Shark’s bold move to honour promise',
#  'Manly succession plan set in motion',
#  'Serena’s step-mum concedes defeat in $1.4m scandal',
#  '$81 off bestselling ASICS Gel-Kayano 29',
#  '‘No more stiff neck’: Top pillow for side sleepers',
#  'Apple’s latest AirPods spotted on sale',
#  'Summer-ready Birkenstocks on sale from just $79',
#  '$150 pair that are a perfect dupe for Hermes',
#  'Dark warning for Aussie homeowners',
#  'Star signs most likely to be serial killers',
#  '‘Disgusting’: Backlash to Kanye’s wild claim',
#  'Princess Mary pulled into ‘difficult’ royal row',
#  'Vegan protester making thousands',
#  'Shocking act disturbs Australian TV star',
#  'Mum’s ‘experiment’ turns into $3.7m idea',
#  'Millions to go beyond ‘quiet quitting’',
#  'Shopping hack Aussie tourists don’t know about',
#  'Aussie Netflix hit the world is obsessed with',
#  "Real reason you can't use your phone on plane",
#  'Mystery surrounding sex act finally solved',
#  "'Staggering': Disturbing trend at Aussie brands",
#  "Queen's biggest wish before her death",
#  "'Chaos': Rain bomb to smash Australia",
#  'Proof Keanu Reeves may be the nicest guy on Earth',
#  'Five signs your partner wants a divorce',
#  'Aussies jump on popular travel trend',
#  "'Regrettable': Adam Levine cheating scandal explodes",
#  "Truth about Princess Kate's secret double life",
#  'New law to get Boomers to sell their homes',
#  "Fans accuse Harry of 'disrespectful' act",
#  "'Return it': War erupts over Queen’s $591m jewel",
#  "Meghan blindsided by kids' new titles",
#  "'Dead money': Aussies refusing to buy house",
#  'Emotional scenes as world farewells Queen',
#  "Justin Bieber reveals 'horrible' diagnosis",
#  "Who will inherit Queen's most precious tiaras",
#  "'Unrelenting': Country on the brink of disaster",
#  "'Incredible': New show everyone is obsessed with",
#  'Meghan request that delayed Fab Four walk',
#  'Best looks from Emmy Awards red carpet',
#  "Surprise reaction to Meghan's 'lovely' act",
#  "Fans call out William's behaviour towards Kate",
#  'Queen Elizabeth’s most playful moments',
#  "'Much-loved': Harry and William’s touching tribute",
#  "'Finally': Apple reveals huge iPhone change",
#  'Huge change coming to Aussie cash',
#  "The Queen's three most defining moments",
#  'Queen Elizabeth’s iconic life in pictures',
#  'Sexuality type we don’t talk about',
#  'Woman who identifies as a wolf cops backlash',
#  '‘Rubbish’: Real reason Tracy Grimshaw quit',
#  "'Not the truth': Film's wild drama explained",
#  "Rare weather event 'SAM' to smash Australia",
#  'Best Nintendo 64 games of all time',
#  "New dating trend as 'hook-up' culture dies out",
#  'Surprise Aussie city wins world’s ‘coolest’ street',
#  'What really killed Princess Diana',
#  'Wild new Taylor Swift conspiracy theory',
#  "'Lyn is dead': Bombshell verdict in murder trial",
#  "'Designer vagina’ surgery is booming",
#  'The Aussie suburbs with ‘ridiculous’ rent hikes',
#  'Four reasons men get paid considerably more',
#  "'This is it': Why you won't see actor anymore",
#  "Scary trap in new 'quiet quitting' trend",
#  'Dangerous sex act on the rise',
#  'Why women everywhere hate this man',
#  "'Rare event': Aussies brace for six months of rain",
#  "Aussies saving a motza with 'cash stuffing’ trend",
#  "'Missing' Aussie actor found in LA jail after date",
#  '‘I’m not talking to you’: Saudi prince erupts',
#  '15 famous sayings with weird origins']

# %%
articles = soup.find_all('p', class_='storyblock_standfirst g_font-body-s')

article_li = []

for article in articles:
    article_li.append(article.text)

article_li
# Out:
# ['Tragic scenes are unfolding following the attack on a pre-school in Nong Bua Lamphu, in the north-east of Thailand.',
#  'Explosive footage has emerged after a barista copped homophobic abuse last week from a top Sydney real estate agent.',
#  'The son of Australian icon Steve Irwin has released a new book in honour of his father’s passion, and it’s selling out fast.   ',
#  'Brittany Higgins has been questioned about when she met Lisa Wilkinson to record an interview for the show and air accusations against her alleged rapist.',
#  'The first arrest in the fallout of the Optus cyber attack has been made, with a man taken into custody by the AFP. ',
#  'Tesla billionaire Elon Musk has continued to agitate political pundits with his proposed solutions to the Ukraine conflict. ',
#  'An NRLW star has revealed she is devastated and fears the worst after a new body-shaming incident that is “just sad”.',
#  'Former Big Bash League cricketer Sandeep Lamichhane returned to Nepal on Thursday to face rape charges.',
#  'Two of Australia’s most populated states are in the path of a severe storm supercell which could possibly bring tornadoes with it. ',
#  'After months of speculation, Cameron Munster has finally made a decision on whether or not he will be a one-club footballer.',
#  'An American woman in Sydney claims she was hounded by an “obsessed” stalker after she posted an ad looking for a housemate. ',
#  'The iconic shoe brand is offering massive discounts on its bestselling range of summer sandals and slides. ',
#  'Visitors to a popular Sydney beach have come across a disturbing sight washed up in the sand. ',
#  'After months of speculation, Cameron Munster has finally made a decision on whether or not he will be a one-club footballer.',
#  'An upsetting picture has emerged as shocking figures reveal the scale of a shameful Australian trend. Money is being raised for the boy in this photo.',
#  'Workers have been warned of a “cooked” commute home after wet weather causes a nightmare breakdown on a major CBD track.',
#  'Giants forward Haneen Zreika will miss next weekend’s AFLW match against Hawthorn to avoid wearing the team’s pride jumper.',
#  'Accused chess cheater Hans Niemann has won another match – after going through a process that left viewers in stitches.',
#  'An Aussie couple forked out $52,000 on what would be their last overseas trip, but they had no idea what was to happen after it got cancelled. ',
#  'A Sydney mum has spoken out about her family’s “nightmare” with a “monstrosity” being built next door by a Chinese developer.',
#  'The government is responding to a “staggering” increase in skills shortages, after a new report showed professional occupations are struggling more than ever.',
#  'Nearly 5 million Australians will receive an ongoing and automatic cash boost from today. Find out who’s eligible.',
#  'There’s a “fatal flaw” people are making when it comes to money and some “controversial” changes need to be made.',
#  'Police have made a decision on charges after AFL legend Wayne Carey dropped a bag of white powder from his pocket at Perth’s Crown Casino.',
#  'One of the highest-profile negotiations of the AFL Trade Period has spectacularly fallen apart leaving one club fuming. ',
#  'Nick Kyrgios is in such good form this season that even he can’t believe some of the things he’s able to do at the moment.',
#  'A Collingwood star has given a stinging response over a commentator’s claim surrounding a swirling AFL trade period rumour.',
#  'Eels star Ryan Matterson continues to pay the price for his controversial move to cop a three-match ban rather than a $4000 fine. ',
#  'LIV Golf players want Greg Norman to make good on his deal to get them crucial world ranking points and he’s made a bold move to try to make that happen. ',
#  'Manly are still considering the end of the Des Hasler era at the club with a former coach of the year in line for a second chance.',
#  'Serena Williams’ step-mum has run out of luck after a five-year scandal of document forgery claims, bankruptcy and a family fortune. ']

# %%
article_li[1]
# Out:
# 'Explosive footage has emerged after a barista copped homophobic abuse last week from a top Sydney real estate agent.'

# %%
df = pd.DataFrame(list(zip(title_li, article_li)))
df
# Out:
#                                                     0  \
# 0   HIGGINS ON THE STAND: Brittany questioned in c...
# 1        ‘My heart aches’: Iconic CBD venues to close
# 2                  Queen’s stunning last act revealed
# 3          ‘Gross’ wedding tradition women keep doing
# 4          Twist after no one shows up to boy’s party
# 5            1000 workers needed: WFH with big salary
# 6        Devastating reason behind ABC star’s absence
# 7      Rollercoaster victim’s final post before crash
# 8        Don’t fall for ‘toxic’ new dating phenomenon
# 9                 Public proposal goes horribly wrong
# 10           Hilarious signs seen at airport arrivals
# 11  Hadis, Minoo and Ghazaleh: the women victims o...
# 12              One thing Aussies have stopped buying
# 13     Rollercoaster victim’s final post before crash
# 14  Only a true fan will score 100% on this all-Au...
# 15          ‘Screw her!’: TV host blasts Olivia Wilde
# 16                      Kochie breaks down on live TV
# 17                 ‘Clowns’: Meghan and Harry slammed
# 18           Desperate plea amid Britney family drama
# 19               Fury over next year’s Met Gala theme
# 20      Hostie ‘whacked with crutch’ in flight lunacy
# 21              One thing Aussies have stopped buying
# 22        Latrell Mitchell fumes at shocking NRL snub
# 23         Sad story behind insane price of two beers
# 24                Bumper AFL trade nearly a done deal
# 25        Netflix rejects ‘panicked’ Meghan and Harry
# 26            ‘Aliens’ attacking people on the Subway
# 27          Suspicions as 433 people win huge jackpot
# 28    Star blames ‘straight people’ for film flopping
# 29      Chess star ‘likely cheated’ 100 times: report
# 30         Iconic spooky restaurants’ $7m price hopes
# 31      Former Bible house now an architectural dream
# 32    Boy George lists London gothic mansion for $28m
# 33             Fury over model’s ‘brownie lips’ trend
# 34          Aldi pizzas ranked with surprising winner
# 40  Kanye West has sparked more controversy with a...
# 41  Explosive new claims have surfaced about Brang...
# 42  Nintendo has released its first look at the up...
# 43  These brands are kicking major goals as Austra...
# 44  The AirPods Pro (2nd Gen) are on sale for the ...
# 45  A rainfall record which has stood for more tha...
# 46  A photograph of a trailer-towing ute parked ac...
# 47  Countless Australians are set to be more heavi...
# 48  An alarming amount of personal information has...
# 49  Harvey Norman and Latitude Finance are facing ...
# 50  A number of Queensland families were excited t...
# 51  The Australian sharemarket has boomed on Wedne...
# 52  An NRL star has been caught up in a nightclub ...
# 53  Eels forward Ryan Matterson has explained why ...
# 54  Australian netball star Gretel Bueta has pulle...
# 55  A future superstar of Aussie cricket was born ...
# 56  Andrew Thorburn should never have been hired a...
# 57  Football Australia has come down hard after an...
# 58  The independent panel formed to investigate sh...
# 59  The Penrith Panthers have been dragged over th...

# %%
# df.rename(["title", "article"], axis='columns')
df.columns = ['title','article']
df.head(5)
# Out:
#                                                title  \
# 0  HIGGINS ON THE STAND: Brittany questioned in c...
# 1       ‘My heart aches’: Iconic CBD venues to close
# 2                 Queen’s stunning last act revealed
# 3         ‘Gross’ wedding tradition women keep doing
# 4         Twist after no one shows up to boy’s party
#
#                                              article
# 0  Brittany Higgins has taken the stand on the se...
# 1  The owner of an iconic Melbourne bar has calle...
# 2  A friend of the Queen has claimed she actively...
# 3  There’s a stark reason why marriage is good fo...
# 4  A birthday boy left devastated after no one sh...

# %%
df.to_csv("scraped data.csv")

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.news.com.au/lifestyle/food/restaurants-bars/my-heart-aches-iconic-melbourne-cbd-venues-bar-americano-and-pentolina-to-close/news-story/3058ae72173263c24e01ad87f140029a"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.title.text
# Out:
# 'Melbourne CBD: Bar Americano and Pentolina announce closures | news.com.au — Australia’s leading news site'

# %%
title = soup.title.text.strip()
print(title)
# Out:
# Melbourne CBD: Bar Americano and Pentolina announce closures | news.com.au — Australia’s leading news site

# %%
articles = soup.body.find_all('p')
article_text = ""
for article in articles:
    article_text += article.text

# %%
article_text
# Out:
# 'The owner of an iconic Melbourne bar has called on the city to “get its sh*t together” as they announce a sad departure from the CBD.The owner of an iconic Melbourne bar said the city was losing the “heart of what made it so great” as he confirmed he was one of two CBD institutions shutting their doors this year.Bar Americano, a hole-in-the-wall cocktail bar on Presgrave Place, confirmed on social media on Tuesday that it had been unable to renew its lease with the building’s new owner.The news came as Pentolina, a pasta restaurant on Little Collins St, also announced via Instagram that it was closing this Christmas. “Times are changing and Melbourne needs to get its sh*t together, we’re losing the heart of what made it so great,” Bar Americano wrote on Instagram. “My heart aches for small businesses like this that cannot win against landlords and developers.”Bar Americano, run by Matt Bax, has operated in the same location for the past decade. Other media outlets have reported that the building in which Bar Americano operates was bought in April by a company owned by George Sykiotis, once a partner in George Calombaris’s restaurants. “I survived 11 years in Pelgrave but I didn’t survive a new landlord,” Bar Americano wrote on Instagram. Bar Americano and Pentolina will follow the likes of other well-known Melbourne restaurants and bars to have closed since the onset of the pandemic, such as Bar Saracens and Madame Brussels. On Tuesday, Pentolina wrote on Instagram: “It breaks our hearts to inform you that we’ll be closing the doors to our little Collins Street pasta haven at Christmas.“Needless to say we’re devastated, and we’re exploring alternative options for keeping the Pentolina spirit alive in another location.”They wrote they had been unable to come to an agreement to renew their lease with their new landlords. Our Apps'

# %%
data_dict = {
    'title' : title,
    'article' : article_text
}

# %%
import pickle
filename = 'nlp_logistical_regression_model.sav'
loaded_model = pickle.load(open(filename, 'rb'))
# Out:
# /Users/alexanderpowers/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/sklearn/base.py:338: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data = {'title': [title],
    'text':[article_text],}
input_data = pd.DataFrame.from_dict(data)
input_data
# Out:
#                                                title  \
# 0  ‘My heart aches’: Iconic Melbourne CBD venues ...
#
#                                                 text
# 0  The owner of an iconic Melbourne bar said the ...

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]',' ',content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)
    return stemmed_content

# %%
input_data['text'] = input_data['text'].apply(stemming)

# %%
X = input_data['text'].values
vectorizer = TfidfVectorizer()
vectorizer.fit(X)
X = vectorizer.transform(X)

# %%
prediction = loaded_model.predict(X)
prediction
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/pf/bkzd2xbj5dsgv5y_gv6jf7200000gn/T/ipykernel_12724/2585356224.py in <module>
# ----> 1 prediction = loaded_model.predict(X)
#       2 prediction
#
# ~/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# ~/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     405         check_is_fitted(self)
#     406
# --> 407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     408         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     409         return scores.ravel() if scores.shape[1] == 1 else scores
#
# ~/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     583
#     584         if not no_val_X and check_params.get("ensure_2d", True):
# --> 585             self._check_n_features(X, reset=reset)
#     586
#     587         return out
#
# ~/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     399         if n_features != self.n_features_in_:
#     400             raise ValueError(
# --> 401                 f"X has {n_features} features, but {self.__class__.__name__} "
#     402                 f"is expecting {self.n_features_in_} features as input."
#     403             )
#
# ValueError: X has 112 features, but LogisticRegression is expecting 17128 features as input.
